# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Downloads/Big Game Census data/uscensusbureau-big-game-census-data-visualization/Big Game Census data.xlsx')
pop_2016 = pd.read_excel('Downloads/Big Game Census data/uscensusbureau-big-game-census-data-visualization/All Places Census 2016 Population Estimates.xlsx')
pop_2017 = pd.read_excel('Downloads/Big Game Census data/uscensusbureau-big-game-census-data-visualization/All states Census 2017 Population Estimates.xlsx')

# %%
df.head()
# Out:
#         Player Name Player Jersey Number Player Position  Player Age  \
# 0    Devin McCourty                  #32            S/FS        30.0
# 1    Danny Amendola                  #80        PR/WR/KR        32.0
# 2  Johnson Bademosi                  #29     CB/SPTM/RCB        27.0
# 3       Chris Hogan                  #15              WR        29.0
# 4     James Develin                  #46           RB/FB        29.0
#
#    Player Weight (lbs.) Years Played Player Birthplace (city, town, etc.)  \
# 0                 195.0            8                               Nanuet
# 1                 190.0            9                        The Woodlands
# 2                 206.0            6                        Silver Spring
# 3                 210.0            5                              Wyckoff
# 4                 255.0            5                        Gilbertsville
#
#   Player Birth State    Player Birthplace (Combo) Player College  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 24 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Player Name                                               119 non-null    object
#  1   Player Jersey Number                                      118 non-null    object
#  2   Player Position                                           118 non-null    object
#  3   Player Age                                                118 non-null    float64
#  4   Player Weight (lbs.)                                      118 non-null    float64
#  5   Years Played                                              118 non-null    object
#  6   Player Birthplace (city, town, etc.)                      118 non-null    object
#  7   Player Birth State                                        118 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Player Name                                                 2
# Player Jersey Number                                        3
# Player Position                                             3
# Player Age                                                  3
# Player Weight (lbs.)                                        3
# Years Played                                                3
# Player Birthplace (city, town, etc.)                        3
# Player Birth State                                          3
# Player Birthplace (Combo)                                   3
# Player College                                              3
# Player Team                                                 3
# Conference                                                  3
# 2016 Population Estimates (except where otherwise noted)    3
# State GEO ID                                                3
# Full GEOID                                                  3
# ...

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118 entries, 0 to 117
# Data columns (total 24 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Player Name                                               118 non-null    object
#  1   Player Jersey Number                                      118 non-null    object
#  2   Player Position                                           118 non-null    object
#  3   Player Age                                                118 non-null    float64
#  4   Player Weight (lbs.)                                      118 non-null    float64
#  5   Years Played                                              118 non-null    object
#  6   Player Birthplace (city, town, etc.)                      118 non-null    object
#  7   Player Birth State                                        118 non-null    object
# ...

# %%
df.describe()
# Out:
#        Player Age  Player Weight (lbs.)  State GEO ID  \
# count  118.000000            118.000000    118.000000
# mean    26.720339            243.881356     28.330508
# std      3.653556             45.959322     17.071521
# min     21.000000            167.000000      1.000000
# 25%     24.000000            205.000000     12.000000
# 50%     26.000000            238.000000     31.000000
# 75%     29.000000            274.000000     40.500000
# max     40.000000            350.000000     75.000000
#
#        Latitude (player birthplace)  Longitude (player birthplace)  \
# count                    118.000000                     118.000000
# mean                      35.566567                     -92.820792
# std                        7.449830                      20.707252
# min                      -14.252294                    -170.713450
# 25%                       32.416135                     -97.764743
# 50%                       36.164258                     -86.614908
# ...

# %%
df_1 = df.drop(['Number from City','Number of Records',
                'American FactFinder Link for more Census data points',
                'Quickfacts Link','State Data Link',
                'Source (Population States 2017)',
               'Birthplace, Population Data Source'],axis=1)

# %%
pop_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19510 entries, 0 to 19509
# Data columns (total 12 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Geographic ID                              19510 non-null  object
#  1   GEOID 2                                    19510 non-null  int64
#  2   Geography, full name (City, State)         19510 non-null  object
#  3   April 1, 2010 - Census                     19510 non-null  object
#  4   April 1, 2010 - Estimates Base             19510 non-null  int64
#  5   Population Estimate (as of July 1) - 2010  19510 non-null  int64
#  6   Population Estimate (as of July 1) - 2011  19510 non-null  int64
#  7   Population Estimate (as of July 1) - 2012  19510 non-null  int64
#  8   Population Estimate (as of July 1) - 2013  19510 non-null  int64
#  9   Population Estimate (as of July 1) - 2014  19510 non-null  int64
# ...

# %%
pop_2016_1 = pop_2016.drop(['April 1, 2010 - Census','April 1, 2010 - Estimates Base',
                              'Population Estimate (as of July 1) - 2010',
                              'Population Estimate (as of July 1) - 2011',
                              'Population Estimate (as of July 1) - 2012',
                              'Population Estimate (as of July 1) - 2013',
                              'Population Estimate (as of July 1) - 2014',
                              'Population Estimate (as of July 1) - 2015'],axis=1)

# %%
pop_2016_1.head()
# Out:
#       Geographic ID  GEOID 2 Geography, full name (City, State)  \
# 0  1620000US0100124   100124            Abbeville city, Alabama
# 1  1620000US0100460   100460           Adamsville city, Alabama
# 2  1620000US0100484   100484              Addison town, Alabama
# 3  1620000US0100676   100676                Akron town, Alabama
# 4  1620000US0100820   100820            Alabaster city, Alabama
#
#    Population Estimate (as of July 1) - 2016
# 0                                       2603
# 1                                       4360
# 2                                        738
# 3                                        334
# 4                                      32948

# %%
pop_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   GEOID                                      52 non-null     object
#  1   GEOID2                                     52 non-null     int64
#  2   Geography Name                             52 non-null     object
#  3   April 1, 2010 - Census                     52 non-null     int64
#  4   April 1, 2010 - Estimates Base             52 non-null     int64
#  5   Population Estimate (as of July 1) - 2010  52 non-null     int64
#  6   Population Estimate (as of July 1) - 2011  52 non-null     int64
#  7   Population Estimate (as of July 1) - 2012  52 non-null     int64
#  8   Population Estimate (as of July 1) - 2013  52 non-null     int64
#  9   Population Estimate (as of July 1) - 2014  52 non-null     int64
# ...

# %%
pop_2017_1 = pop_2017.drop(['April 1, 2010 - Census','April 1, 2010 - Estimates Base',
                            'Population Estimate (as of July 1) - 2010',
                            'Population Estimate (as of July 1) - 2011',
                            'Population Estimate (as of July 1) - 2012',
                            'Population Estimate (as of July 1) - 2013',
                            'Population Estimate (as of July 1) - 2014',
                            'Population Estimate (as of July 1) - 2015'],axis=1)

# %%
pop_2017_1.head()
# Out:
#          GEOID  GEOID2 Geography Name  \
# 0  0400000US01       1        Alabama
# 1  0400000US02       2         Alaska
# 2  0400000US04       4        Arizona
# 3  0400000US05       5       Arkansas
# 4  0400000US06       6     California
#
#    Population Estimate (as of July 1) - 2016  \
# 0                                    4860545
# 1                                     741522
# 2                                    6908642
# 3                                    2988231
# 4                                   39296476
#
#    Population Estimate (as of July 1) - 2017
# 0                                    4874747
# 1                                     739795
# 2                                    7016270
# 3                                    3004279
# 4                                   39536653

# %%
df_1.head()
# Out:
#         Player Name Player Jersey Number Player Position  Player Age  \
# 0    Devin McCourty                  #32            S/FS        30.0
# 1    Danny Amendola                  #80        PR/WR/KR        32.0
# 2  Johnson Bademosi                  #29     CB/SPTM/RCB        27.0
# 3       Chris Hogan                  #15              WR        29.0
# 4     James Develin                  #46           RB/FB        29.0
#
#    Player Weight (lbs.) Years Played Player Birthplace (city, town, etc.)  \
# 0                 195.0            8                               Nanuet
# 1                 190.0            9                        The Woodlands
# 2                 206.0            6                        Silver Spring
# 3                 210.0            5                              Wyckoff
# 4                 255.0            5                        Gilbertsville
#
#   Player Birth State    Player Birthplace (Combo) Player College  Player Team  \
# ...

# %%
df_1.rename(columns={'Full GEOID': 'GEOID'}, inplace=True)

# %%
df_merged = pd.merge(df_1,pop_2017_1,how='inner',on='GEOID')

# %%
df_merged.head()
# Out:
#         Player Name Player Jersey Number Player Position  Player Age  \
# 0    Devin McCourty                  #32            S/FS        30.0
# 1    Danny Amendola                  #80        PR/WR/KR        32.0
# 2  Johnson Bademosi                  #29     CB/SPTM/RCB        27.0
# 3       Chris Hogan                  #15              WR        29.0
# 4     James Develin                  #46           RB/FB        29.0
#
#    Player Weight (lbs.) Years Played Player Birthplace (city, town, etc.)  \
# 0                 195.0            8                               Nanuet
# 1                 190.0            9                        The Woodlands
# 2                 206.0            6                        Silver Spring
# 3                 210.0            5                              Wyckoff
# 4                 255.0            5                        Gilbertsville
#
#   Player Birth State    Player Birthplace (Combo) Player College  ...  \
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 21 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Player Name                                               115 non-null    object
#  1   Player Jersey Number                                      115 non-null    object
#  2   Player Position                                           115 non-null    object
#  3   Player Age                                                115 non-null    float64
#  4   Player Weight (lbs.)                                      115 non-null    float64
#  5   Years Played                                              115 non-null    object
#  6   Player Birthplace (city, town, etc.)                      115 non-null    object
#  7   Player Birth State                                        115 non-null    object
# ...

# %%
df_merged['Years Played'].unique()
# Out:
# array([8, 9, 6, 5, 4, 2, 3, 1, 10, 15, 12, 11, 'R', 7, 18, 13, 14],
#       dtype=object)

# %%
#df_merged.to_excel('census_data_merged.xlsx')
